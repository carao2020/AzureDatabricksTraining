td><td>0</td><td>furiously special f</td><td>1996</td></tr><tr><td>962149</td><td>120001</td><td>O</td><td>106121.36</td><td>1997-11-04</td><td>5-LOW</td><td>Clerk#000000727</td><td>0</td><td>furiously special f</td><td>1997</td></tr><tr><td>851648</td><td>46747</td><td>F</td><td>104150.25</td><td>1994-06-11</td><td>4-NOT SPECIFIED</td><td>Clerk#000000001</td><td>0</td><td>furiously special f</td><td>1994</td></tr></tbody></table></div>

# %%
import pyspark.sql.functions as f
display(ordersDF.filter("O_ORDERSTATUS = 'O'").groupBy("O_OrderYear","O_ORDERPRIORITY").agg(count("*").alias("TotalOrders")).orderBy("TotalOrders", ascending=False).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>O_OrderYear</th><th>O_ORDERPRIORITY</th><th>TotalOrders</th></tr></thead><tbody><tr><td>1996</td><td>1-URGENT</td><td>46014</td></tr><tr><td>1996</td><td>4-NOT SPECIFIED</td><td>45776</td></tr><tr><td>1997</td><td>4-NOT SPECIFIED</td><td>45754</td></tr><tr><td>1997</td><td>2-HIGH</td><td>45689</td></tr><tr><td>1997</td><td>1-URGENT</td><td>45662</td></tr><tr><td>1996</td><td>3-MEDIUM</td><td>45657</td></tr><tr><td>1996</td><td>5-LOW</td><td>45639</td></tr><tr><td>1997</td><td>5-LOW</td><td>45580</td></tr><tr><td>1996</td><td>2-HIGH</td><td>45540</td></tr><tr><td>1997</td><td>3-MEDIUM</td><td>45098</td></tr><tr><td>1995</td><td>2-HIGH</td><td>28653</td></tr><tr><td>1995</td><td>5-LOW</td><td>28610</td></tr><tr><td>1995</td><td>3-MEDIUM</td><td>28438</td></tr><tr><td>1995</td><td>4-NOT SPECIFIED</td><td>28410</td></tr><tr><td>1995</td><td>1-URGENT</td><td>28187</td></tr><tr><td>1998</td><td>5-LOW</td><td>27010</td></tr><tr><td>1998</td><td>3-MEDIUM</td><td>26843</td></tr><tr><td>1998</td><td>1-URGENT</td><td>26652</td></tr><tr><td>1998</td><td>4-NOT SPECIFIED</td><td>26582</td></tr><tr><td>1998</td><td>2-HIGH</td><td>26536</td></tr></tbody></table></div>

# %%
# Saving the parquetFiles read in Delta format
ordersDF.write.format("delta").mode("overwrite").partitionBy("O_OrderYear").save("/mnt/Gen2/Orders/OrdersDelta/")

# %%
display(dbutils.fs.ls("/mnt/Gen2/Orders/OrdersDelta/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1992/</td><td>O_OrderYear=1992/</td><td>0</td><td>1669332878000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1993/</td><td>O_OrderYear=1993/</td><td>0</td><td>1669332879000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1994/</td><td>O_OrderYear=1994/</td><td>0</td><td>1669332879000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1995/</td><td>O_OrderYear=1995/</td><td>0</td><td>1669332880000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1996/</td><td>O_OrderYear=1996/</td><td>0</td><td>1669332880000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1997/</td><td>O_OrderYear=1997/</td><td>0</td><td>1669332880000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1998/</td><td>O_OrderYear=1998/</td><td>0</td><td>1669332880000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1669332877000</td></tr></tbody></table></div>

# %%
# Checking the number of files created in 1993 folder. There are 9 files created
display(dbutils.fs.ls("dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1993/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1993/part-00000-8a6ce33b-8de1-419a-bc72-56951a7bed31.c000.snappy.parquet</td><td>part-00000-8a6ce33b-8de1-419a-bc72-56951a7bed31.c000.snappy.parquet</td><td>1000072</td><td>1669332879000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1993/part-00001-9720dd6d-d2a4-4e64-b1ac-7632a3187450.c000.snappy.parquet</td><td>part-00001-9720dd6d-d2a4-4e64-b1ac-7632a3187450.c000.snappy.parquet</td><td>1004892</td><td>1669332879000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1993/part-00002-60561b4e-0579-401c-a12d-c78bbdfae768.c000.snappy.parquet</td><td>part-00002-60561b4e-0579-401c-a12d-c78bbdfae768.c000.snappy.parquet</td><td>996390</td><td>1669332879000</td></tr><tr><td>dbfs:/mnt/Gen2/Orders/OrdersDelta/O_OrderYear=1993/part-00003-c76fcc20-e5f9-4e29-adb7-66f35ea1a2dc.c000.snappy.parquet</td><td>part-00003-c76fcc20-e5f9-4e29-adb7-66f35ea1a2dc.c000.snappy.parquet</td><td>752087</td><td>1669332879000</td></tr></tbody></table></div>

# %%
display(spark.sql("DROP TABLE  IF EXISTS Orders"))

display(spark.sql("CREATE TABLE Orders USING DELTA LOCATION '/mnt/Gens/Orders/OrdersDelta'"))
                  
display(spark.sql("OPTIMIZE Orders ZORDER BY (O_ORDERPRIORITY)"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <command-2253846730212416> in <cell line: 5>()
#       3 display(spark.sql("CREATE TABLE Orders USING DELTA LOCATION '/mnt/Gens/Orders/OrdersDelta'"))
#       4
# ----> 5 display(spark.sql("OPTIMIZE Orders ZORDER BY (O_ORDERPRIORITY)"))
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery, **kwargs)
#    1117             sqlQuery = formatter.format(sqlQuery, **kwargs)
#    1118         try:
# -> 1119             return DataFrame(self._jsparkSession.sql(sqlQuery), self)
#    1120         finally:
#    1121             if len(kwargs) > 0:
#
# /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     200                 # Hide where the exception came from that shows a non-Pythonic
#     201                 # JVM exception message.
# --> 202                 raise converted from None
#     203             else:
#     204                 raise
#
# IllegalArgumentException: Z-Ordering column O_ORDERPRIORITY does not exist in data schema.

# %%
# Lets re-execuete the same query used in cell 4
from pyspark.sql.functions import count
ordersDeltaDF = spark.read.format("Delta").load("/mnt/Gen2/Orders/OrdersDelta/")
display(ordersDeltaDF.filter("O_ORDERSTATUS = 'O'").groupBy("O_OrderYear","O_ORDERPRIORITY").agg(count("*").alias("TotalOrders")).orderBy("TotalOrders", ascending=False).limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th