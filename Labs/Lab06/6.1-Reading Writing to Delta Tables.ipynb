# %%
storageAccount="sriniadlsgen2999"
mountpoint = "/mnt/Gen2"
storageEndPoint ="abfss://rawdata@{}.dfs.core.windows.net/".format(storageAccount)
print ('Mount Point ='+mountpoint)

#ClientId, TenantId and Secret is for the Application(ADLSGen2App) was have created as part of this recipe
clientID ="c8af7163-2d53-45b7-add9-16296f29ba72"
tenantID ="8f264c1d-6340-44fd-9e9f-e71f7d31df64"
clientSecret ="D7V8Q~M1GL4~DQLHWJlrom~pw~fIULJMOdU.6a3P"
oauth2Endpoint = "https://login.microsoftonline.com/{}/oauth2/token".format(tenantID)


configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": clientID,
           "fs.azure.account.oauth2.client.secret": clientSecret,
           "fs.azure.account.oauth2.client.endpoint": oauth2Endpoint}

try:
  dbutils.fs.mount(
  source = storageEndPoint,
  mount_point = mountpoint,
  extra_configs = configs)
except:
    print("Already mounted...."+mountpoint)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Mount Point =/mnt/Gen2Source
# Already mounted..../mnt/Gen2Source
# </div>

# %%
display(dbutils.fs.ls("/mnt/Gen2/Customer/parquetFiles"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/_SUCCESS</td><td>_SUCCESS</td><td>0</td><td>1669164147000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/_committed_5620084791754389861</td><td>_committed_5620084791754389861</td><td>2034</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/_committed_9130614487565958443</td><td>_committed_9130614487565958443</td><td>1024</td><td>1669163892000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/_started_5620084791754389861</td><td>_started_5620084791754389861</td><td>0</td><td>1669164145000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/_started_9130614487565958443</td><td>_started_9130614487565958443</td><td>0</td><td>1669163891000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00000-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-148-1-c000.snappy.parquet</td><td>part-00000-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-148-1-c000.snappy.parquet</td><td>1247732</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00001-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-149-1-c000.snappy.parquet</td><td>part-00001-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-149-1-c000.snappy.parquet</td><td>1251539</td><td>1669164145000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00002-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-150-1-c000.snappy.parquet</td><td>part-00002-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-150-1-c000.snappy.parquet</td><td>1248779</td><td>1669164145000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00003-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-151-1-c000.snappy.parquet</td><td>part-00003-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-151-1-c000.snappy.parquet</td><td>1247495</td><td>1669164145000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00004-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-152-1-c000.snappy.parquet</td><td>part-00004-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-152-1-c000.snappy.parquet</td><td>1244953</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00005-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-153-1-c000.snappy.parquet</td><td>part-00005-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-153-1-c000.snappy.parquet</td><td>1246838</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00006-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-154-1-c000.snappy.parquet</td><td>part-00006-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-154-1-c000.snappy.parquet</td><td>1251055</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00007-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-155-1-c000.snappy.parquet</td><td>part-00007-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-155-1-c000.snappy.parquet</td><td>1251335</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00008-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-156-1-c000.snappy.parquet</td><td>part-00008-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-156-1-c000.snappy.parquet</td><td>1249407</td><td>1669164146000</td></tr><tr><td>dbfs:/mnt/Gen2/Customer/parquetFiles/part-00009-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-157-1-c000.snappy.parquet</td><td>part-00009-tid-5620084791754389861-e4d3d69f-f628-4d3b-abeb-76bc5507b070-157-1-c000.snappy.parquet</td><td>1249107</td><td>1669164146000</td></tr></tbody></table></div>

# %%
db = "tpchdb"
 
spark.sql(f"CREATE DATABASE IF NOT EXISTS {db}")
spark.sql(f"USE {db}")
 
spark.sql("SET spark.databricks.delta.formatCheck.enabled = false")
spark.sql("SET spark.databricks.delta.properties.defaults.autoOptimize.optimizeWrite = true")
# Out:
# Out[2]: DataFrame[key: string, value: string]

# %%
import random
from datetime import datetime
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *

# %% [markdown]
# ### Reading Customer parquet files from the mount point and writing to Delta tables.

# %%
#Reading parquet files and adding a new column to the dataframe and writing to delta table
cust_path = "/mnt/Gen2/Customer/parquetFiles"
 
df_cust = (spark.read.format("parquet").load(cust_path)
      .withColumn("timestamp", current_timestamp()))
 
df_cust.write.format("delta").option("mergeSchema","true").mode("overwrite").save("/mnt/Gen2/Customer/delta")

# %%
# %sql
-- Creating Delta table 
DROP TABLE IF EXISTS Customer;
CREATE TABLE Customer
USING delta
location "/mnt/Gen2/Customer/delta"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
describe  Customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>C_CUSTKEY</td><td>int</td><td>null</td></tr><tr><td>C_NAME</td><td>string</td><td>null</td></tr><tr><td>C_ADDRESS</td><td>string</td><td>null</td></tr><tr><td>C_NATIONKEY</td><td>smallint</td><td>null</td></tr><tr><td>C_PHONE</td><td>string</td><td>null</td></tr><tr><td>C_ACCTBAL</td><td>double</td><td>null</td></tr><tr><td>C_MKTSEGMENT</td><td>string</td><td>null</td></tr><tr><td>C_COMMENT</td><td>string</td><td>null</td></tr><tr><td>timestamp</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select * from Customer limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>C_CUSTKEY</th><th>C_NAME</th><th>C_ADDRESS</th><th>C_NATIONKEY</th><th>C_PHONE</th><th>C_ACCTBAL</th><th>C_MKTSEGMENT</th><th>C_COMMENT</th><th>timestamp</th></tr></thead><tbody><tr><td>16821</td><td>Customer#000016821</td><td>Gi36LiRpa5YPU9KDs0MheFpHs7Vs6gIushe7</td><td>0</td><td>10-303-361-6412</td><td>5083.84</td><td>HOUSEHOLD</td><td>sly regular requests wake slyly against the bold accounts: regular pinto beans integrate carefully. pinto b</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>144829</td><td>Customer#000144829</td><td>titTLnrmjV2BDBKiNo</td><td>0</td><td>10-209-712-6633</td><td>90.36</td><td>BUILDING</td><td>packages. ruthless dependencies must have to run furiously slyly pending pains. unusua</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>8917</td><td>Customer#000008917</td><td>R,Qu0BWeRzqZ2bSs8gVQ4ply</td><td>0</td><td>10-170-188-9290</td><td>7418.79</td><td>FURNITURE</td><td>onic theodolites. packages boost quickly according to the bold, bold deposits. final accounts are through the exp</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>83163</td><td>Customer#000083163</td><td>TXGVXPf,GnHaeJwmAl</td><td>0</td><td>10-722-703-2387</td><td>2851.1</td><td>MACHINERY</td><td>bold accounts. blithely final instructions believe fluffily furi</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>56550</td><td>Customer#000056550</td><td>juezVnyTIcrOaqqrA6b1pXeJbMclmWB1cp2</td><td>0</td><td>10-969-755-2485</td><td>1652.56</td><td>MACHINERY</td><td>express requests. doggedly final requests are packages. slyly regular platelets engage</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>118830</td><td>Customer#000118830</td><td>kr7Og3YhzvhsQ</td><td>0</td><td>10-425-956-3800</td><td>8525.43</td><td>FURNITURE</td><td>s haggle quickly ironic, final pinto beans. carefully bold packages haggle around</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>49646</td><td>Customer#000049646</td><td>sz0FA1opSV5 MDEbKTKiTkFstXOcKh</td><td>0</td><td>10-457-724-9226</td><td>2388.83</td><td>FURNITURE</td><td>express packages cajole quickly alongside of the idly silent packages? fluffily special idea</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>95816</td><td>Customer#000095816</td><td>55YRkzb,xG2CJmFPhbF</td><td>0</td><td>10-857-823-2735</td><td>8919.51</td><td>BUILDING</td><td>slyly furiously regular theodolites. regular pains impress slyly</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>98334</td><td>Customer#000098334</td><td>JgVncPNT4rXEBuwVaeU4</td><td>0</td><td>10-684-775-4502</td><td>4085.3</td><td>AUTOMOBILE</td><td>lyly bold deposits. silent platelets above the final frets are blithely after the blithely ironic in</td><td>2022-11-24T22:47:14.468+0000</td></tr><tr><td>63498</td><td>Customer#000063498</td><td>FacCDkD,GbTLMieRomaASll</td><td>0</td><td>10-607-363-8404</td><td>1203.91</td><td>MACHINERY</td><td>s. theodolites against the carefully ironic dependencies cajole slyly regular platelets. even realms haggle</td><td>2022-11-24T22:47:14.468+0000</td></tr></tbody></table></div>

# %%
# %sql
-- DML Operations
-- Deleting from Delta table
DELETE FROM Customer WHERE C_CUSTKEY=82533
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
#dbutils.fs.unmount("/mnt/Gen2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/Gen2Source has been unmounted.
# Out[3]: True</div>
