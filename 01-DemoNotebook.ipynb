# %% [markdown]
# # Demo Notebook

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>1669103403000</td></tr></tbody></table></div>

# %%
# %fs ls /databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td><td>1532468253000</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td><td>1455043490000</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td><td>1669108020362</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/delta-sharing/</td><td>delta-sharing/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/identifying-campaign-effectiveness/</td><td>identifying-campaign-effectiveness/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/med-images/</td><td>med-images/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/media/</td><td>media/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/</td><td>nyctaxi/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi-with-zipcodes/</td><td>nyctaxi-with-zipcodes/</td><td>0</td><td>1669108020363</td></tr><tr><td>dbfs:/d ...

# %%
# %fs ls /databricks-datasets/learning-spark-v2/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/learning-spark-v2/.DS_Store</td><td>.DS_Store</td><td>6148</td><td>1602174521000</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/README/</td><td>README/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td><td>1577997727000</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/blogs.json</td><td>blogs.json</td><td>915</td><td>1587070414000</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/cctvVideos/</td><td>cctvVideos/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/flights/</td><td>flights/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/iot-devices/</td><td>iot-devices/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/loans/</td><td>loans/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/mnm_dataset.csv</td><td>mnm_dataset.csv</td><td>1284872</td><td>1587070414000</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/people/</td><td>people/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/sf-airbnb/</td><td>sf-airbnb/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/sf-fire/</td><td>sf-fire/</td><td>0</td><td>1669108021160</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/us_population.json</td><td>us_population.json</td><td>3299821</td><td>1587071146000</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/web1_access_log_20190715-064001.log</td><td>web1_access_log_20190715-064001.log</td><td>22106452</td><td>1587071144000</td></tr></tbody></table></div>

# %% [markdown]
# # Creating  a dataframe by reading CSV file from path
# # /databricks-datasets/learning-spark-v2/mnm_dataset.csv

# %%
#load the data from csv into a dataframe
myDataFrame = spark.read.csv(
    "/databricks-datasets/learning-spark-v2/mnm_dataset.csv",
    header="true",
    inferSchema="true",
)
#show will be shown from Dataframe
myDataFrame.show()
#display first 10 records
display(myDataFrame.limit(10))
#print schema of the dataframe
myDataFrame.printSchema()
# Out:
# +-----+------+-----+
# |State| Color|Count|
# +-----+------+-----+
# |   TX|   Red|   20|
# |   NV|  Blue|   66|
# |   CO|  Blue|   79|
# |   OR|  Blue|   71|
# |   WA|Yellow|   93|
# |   WY|  Blue|   16|
# |   CA|Yellow|   53|
# |   WA| Green|   60|
# |   OR| Green|   71|
# |   TX| Green|   68|
# |   NV| Green|   59|
# |   AZ| Brown|   95|
# |   WA|Yellow|   20|
# |   AZ|  Blue|   75|
# |   OR| Brown|   72|
# |   NV|   Red|   98|
# |   WY|Orange|   45|
# |   CO|  Blue|   52|
# |   TX| Brown|   94|
# |   CO|   Red|   82|
# +-----+------+-----+
# only showing top 20 rows
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>Color</th><th>Count</th></tr></thead><tbody><tr><td>TX</td><td>Red</td><td>20</td></tr><tr><td>NV</td><td>Blue</td><td>66</td></tr><tr><td>CO</td><td>Blue</td><td>79</td></tr><tr><td>OR</td><td>Blue</td><td>71</td></tr><tr><td>WA</td><td>Yellow</td><td>93</td></tr><tr><td>WY</td><td>Blue</td><td>16</td></tr><tr><td>CA</td><td>Yellow</td><td>53</td></tr><tr><td>WA</td><td>Green</td><td>60</td></tr><tr><td>OR</td><td>Green</td><td>71</td></tr><tr><td>TX</td><td>Green</td><td>68</td></tr></tbody></table></div>
# root
#  |-- State: string (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Count: integer (nullable = true)

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>mycustomtable</td><td>false</td></tr></tbody></table></div>

# %%
#write the data from dataframe into a table

myDataFrame.write.mode("overwrite").saveAsTable("myCustomTable")

# %%
# %sql

SHOW TABLES;

SELECT count(*) FROM mycustomtable;

SELECT  * FROM mycustomtable limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>Color</th><th>Count</th></tr></thead><tbody><tr><td>TX</td><td>Red</td><td>20</td></tr><tr><td>NV</td><td>Blue</td><td>66</td></tr><tr><td>CO</td><td>Blue</td><td>79</td></tr><tr><td>OR</td><td>Blue</td><td>71</td></tr><tr><td>WA</td><td>Yellow</td><td>93</td></tr><tr><td>WY</td><td>Blue</td><td>16</td></tr><tr><td>CA</td><td>Yellow</td><td>53</td></tr><tr><td>WA</td><td>Green</td><td>60</td></tr><tr><td>OR</td><td>Green</td><td>71</td></tr><tr><td>TX</td><td>Green</td><td>68</td></tr></tbody></table></div>
